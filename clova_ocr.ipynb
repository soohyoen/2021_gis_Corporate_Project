# %%
import requests
import uuid
import time
import json


api_url = api_url
secret_key = secret_key

image_file = image_file
output_file = output_file
request_json = {
    'images': [
        {
            'format': 'jpg',
            'name': 'test'
        }
    ],
    'requestId': str(uuid.uuid4()),
    'version': 'V2',
    'timestamp': int(round(time.time() * 1000))
}
payload = {'message': json.dumps(request_json).encode('UTF-8')}
files = [
  ('file', open(image_file,'rb'))
]
headers = {
  'X-OCR-SECRET': secret_key
}
response = requests.request("POST", api_url, headers=headers, data = payload, files = files)
res = json.loads(response.text.encode('utf8'))
print(res)
with open(output_file, 'w', encoding='utf-8') as outfile:
    json.dump(res, outfile, indent=4, ensure_ascii=False)
# Out:
# {'version': 'V2', 'requestId': '55a1c5ce-bd73-4c57-bba5-0643c1454575', 'timestamp': 1635301739119, 'images': [{'uid': 'c1a41716bbe74e2eb79fa690308e66f4', 'name': 'test', 'inferResult': 'SUCCESS', 'message': 'SUCCESS', 'validationResult': {'result': 'NO_REQUESTED'}, 'fields': []}]}

# %%
import json

input_data = input_data

with open(input_data, 'r', encoding='utf-8') as f:
    json_data = json.load(f)
print(json.dumps(json_data) )
# Out:
# {"version": "V2", "requestId": "8d078b03-318d-43e7-bf21-fc454934bc9a", "timestamp": 1635297528164, "images": [{"uid": "165294eb6550484f884ce71978a6dcd6", "name": "30", "inferResult": "SUCCESS", "message": "SUCCESS", "validationResult": {"result": "NO_REQUESTED"}, "fields": [{"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 380.0, "y": 166.0}, {"x": 595.0, "y": 166.0}, {"x": 595.0, "y": 206.0}, {"x": 380.0, "y": 206.0}]}, "inferText": "\uc778\ud14c\ub9ac\uc5b4\uacf5\uc0ac", "inferConfidence": 1.0, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 605.0, "y": 166.0}, {"x": 787.0, "y": 166.0}, {"x": 787.0, "y": 206.0}, {"x": 605.0, "y": 206.0}]}, "inferText": "\ud45c\uc900\uacc4\uc57d\uc11c", "inferConfidence": 0.9999, "type": "NORMAL", "lineBreak": true}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 137.0, "y": 286.0}, {"x": 274.0, "y": 286.0}, {"x": 274.0, "y": 309.0}, {"x": 137.0, "y": 309.0}]}, "inferText": "\ubc1c\uc8fc\uc790(\uc2dc\ud589\uc790)", "inferConfidence": 0.9659, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 283.0, "y": 285.0}, {"x": 345.0, "y": 287.0}, {"x": 345.0, "y": 311.0}, {"x": 282.0, "y": 309.0}]}, "inferText": "\uae40\uc0c1\uc724", "inferConfidence": 0.9999, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 354.0, "y": 287.0}, {"x": 407.0, "y": 287.0}, {"x": 407.0, "y": 309.0}, {"x": 354.0, "y": 309.0}]}, "inferText": "(\uc774\ud558", "inferConfidence": 0.9998, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 414.0, "y": 289.0}, {"x": 492.0, "y": 289.0}, {"x": 492.0, "y": 309.0}, {"x": 414.0, "y": 309.0}]}, "inferText": "\"\uac11\"\uc774\ub77c", "inferConfidence": 1.0, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 502.0, "y": 286.0}, {"x": 572.0, "y": 286.0}, {"x": 572.0, "y": 309.0}, {"x": 502.0, "y": 309.0}]}, "inferText": "\ud55c\ub2e4)\uacfc", "inferConfidence": 0.9992, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 585.0, "y": 287.0}, {"x": 719.0, "y": 287.0}, {"x": 719.0, "y": 309.0}, {"x": 585.0, "y": 309.0}]}, "inferText": "\uc218\uae09\uc790(\uc2dc\uacf5\uc790)", "inferConfidence": 0.9432, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 729.0, "y": 286.0}, {"x": 885.0, "y": 286.0}, {"x": 885.0, "y": 309.0}, {"x": 729.0, "y": 309.0}]}, "inferText": "\uc5c5\uc2f8\uc774\ud074(\uc774\uc7ac\uc6b0)", "inferConfidence": 0.9947, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 893.0, "y": 286.0}, {"x": 944.0, "y": 286.0}, {"x": 944.0, "y": 308.0}, {"x": 893.0, "y": 308.0}]}, "inferText": "(\uc774\ud558", "inferConfidence": 1.0, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 955.0, "y": 289.0}, {"x": 1030.0, "y": 289.0}, {"x": 1030.0, "y": 309.0}, {"x": 955.0, "y": 309.0}]}, "inferText": "\"\uc744\"\uc774\ub77c", "inferConfidence": 0.9983, "type": "NORMAL", "lineBreak": true}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 137.0, "y": 315.0}, {"x": 208.0, "y": 315.0}, {"x": 208.0, "y": 340.0}, {"x": 137.0, "y": 340.0}]}, "inferText": "\ud55c\ub2e4)\ub294", "inferConfidence": 0.9997, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 214.0, "y": 317.0}, {"x": 275.0, "y": 317.0}, {"x": 275.0, "y": 340.0}, {"x": 214.0, "y": 340.0}]}, "inferText": "\uc544\ub798\uc640", "inferConfidence": 0.9998, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly": {"vertices": [{"x": 281.0, "y": 317.0}, {"x": 324.0, "y": 317.0}, {"x": 324.0, "y": 340.0}, {"x": 281.0, "y": 340.0}]}, "inferText": "\uac19\uc774", "inferConfidence": 1.0, "type": "NORMAL", "lineBreak": false}, {"valueType": "ALL", "boundingPoly" ...

# %%
x = []

data_fields = json_data['images'][0]['fields']
len(data_fields)

for j in range(len(data_fields)):
    data = json_data["images"][0]["fields"][j]['inferText']
    x.append(data)

res = str.join(' ',x)
res
# Out:
# '인테리어공사 표준계약서 발주자(시행자) 김상윤 (이하 "갑"이라 한다)과 수급자(시공자) 업싸이클(이재우) (이하 "을"이라 한다)는 아래와 같이 계약을 체결한다. 제1조 [공사개요] 1. 공사명 : 성남 연습실 실내 인테리어 마무리 작업 2. 공사장소: 경기도 성남시 중원구 광명로 93번길 지층 3. 공사면적: 약 120m2 4. 공사기간 : 2021년 10월 13일 ~ 2021년 10월 20일 제2조 [공사대금] 1. 총 공사금액 일천사백육십만원정(부가가치세 별도임) (₩ 14,600,000) 1) 1차 대금지급 : 일금 육백만 원정 (6,000,000), 2021년 10월 12일 2) 2차 대금지급 : 일금 삼백만 원정 (₩3,000,000), 2021년 10월 14일 3) 3차 대금지급 : 일금 삼백오십만 원정 (₩3,500,000), 2021년 10월 16일 4) 4차 대금지급 : 일금 이백십만 원정 (₩2,100,000), 작업 완료일 2. " 갑"은 전항의 공사대금지급과 관련하여 정당한 사유 없이 지급을 지연하여서는 안되 며, 지연 시에는 미지급액에 대하여 지급일 다음 날로부터 완제일까지 연 5%의 지연 이자를 지급하여야 한다. 제3조 [공사내역] 1. "을"은 공사착수 전 "갑"에게 작업일정서, 공사내역서를 제출하여 승인을 취득하여야 한다. 2. 공사에 사용할 재료의 품질 및 규격은 설계서와 일치되어야 한다. 다만, 설계도서에 품질·품명이 명확히 규정되지 아니하거나 해당 재료가 품절인 경우 상호 협의하여 달 리 결정할 수 있다. 3. 전항의 합의가 없는 경우 공사에 사용할 재료는 표준품 또는 표준품에 상당하는 재료 로서 계약의 목적을 달성하는데 가장 적합한 것으로 한다. 제4조 [공사의 변경 및 조정 ] 1. 공사진행 중 또는 공사완료 후 "갑"의 요구에 의하여 공사내용을 변경하거나 추가할 경우 "을"은 이에 응할 수 있으며, "갑"은 변경 및 조정에 따르는 추가경비를 "을"에게 지불하여야 한다. 공사완료 후 공사변경은 별도계약에 의하여 처리하여야 한다. 2. "을"은 공사의 원활한 진행 및 계약목적의 효율적 달성을 위해 공사내용 및 공법의 변 경을 "갑"에게 요청할 수 있다. 3. 예정완공일은 공사내용의 변경에 따라 추가로 소요되는 기간을 고려하여 연장할 수 있다. 4. 제1항 및 제2항에 의하여 공사금액이 변경되는 경우 잔금 지급 시 정산한다. 제5조 [계약의 해제 또는 해지 ] 1. "갑" 또는 "을"은 다음 각 호의 1에 해당하는 경우 서면으로 당해 계약의 일부 또는 전부를 해제·해지할 수 있다. 1) "을"이 정당한 사유 없이 착공을 지연시킬 경우 -1-'
